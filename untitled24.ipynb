# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolaynebarret/DataConnect/blob/main/untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **`IMPORTANDO OS ARQUIVOS `**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Carregando os arquivos e lendo as primeiras 5 linhas**

# %%
df_analistas = pd.read_csv('dc_analistas.csv')
print("Carregamento de 'dc_analistas.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:")
print(df_analistas.head())
# Out:
# Carregamento de 'dc_analistas.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:
#   analista_id        analista    squad   senioridade custo_hora data_admissao
# 0      ANL001     Ana Barbosa    ALPHA        Senior     150,00    2021-12-07
# 1      ANL002  Bruno Ipiranga    Bravo         Pleno      95.00    2021-08-30
# 2      ANL003   Carla Esteves  Charlie        Junior      55.00    2024-12-26
# 3      ANL004   Diego Freitas    Delta  Especialista     210.00    2025-07-28
# 4      ANL005   Elisa Werneck     Echo         Pleno      95.00    24/10/2023

# %%
df_projetos = pd.read_csv('dc_projetos.csv')
print("Carregamento de 'dc_projetos.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:")
print(df_projetos.head())
# Out:
# Carregamento de 'dc_projetos.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:
#   projeto_id cliente_id                 nome_projeto          tipo_servico  \
# 0    PRJ0001     CLI013       Dashboard BI - Windsor        Dashboard B.I.
# 1    PRJ0002     CLI022  Diagnóstico de Dados - Umbu  Diagnóstico de Dados
# 2    PRJ0003     CLI051  Pipeline de Dados - Cristal     Pipeline de Dados
# 3    PRJ0004     CLI060        Dashboard BI - Kairós          Dashboard BI
# 4    PRJ0005     CLI020      Modelo Preditivo - Duna      Modelo Preditivo
#
#      squad     status data_inicio data_fim_prevista data_fim_real  \
# 0    Delta  CONCLUÍDO  2024-03-19        2024-05-06    08/05/2024
# 1    Alpha  Cancelado  2024-10-01        2024-10-28           NaN
# 2  Charlie  Concluído  2025-06-16        20/10/2025    10/15/2025
# 3     Echo  Concluído  2024-03-19       25-abr-2024    2024-04-26
# 4     Echo  Concluído  09/12/2024        02/27/2025    2025-03-12
#
#    horas_vendidas valor_contrato
# 0             288            NaN
# 1              89       24044.51
# 2             423       91525.58
# 3             220       47409.01
# 4             338      61.970,49

# %%
df_clientes = pd.read_csv('dc_clientes.csv')
print("Carregamento de 'dc_clientes.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:")
print(df_clientes.head())
# Out:
# Carregamento de 'dc_clientes.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:
#   cliente_id      cliente      setor    porte          cidade              uf  \
# 0     CLI001  Umbu S.A.          NaN  Pequeno  Rio de Janeiro  Rio de Janeiro
# 1     CLI002   Xingu S.A.  Indústria    Médio   Florianópolis              SC
# 2     CLI003  Aurora S.A.      Saúde    Médio        Curitiba              PR
# 3     CLI004    Rubi Ltda  Logística  Pequeno   Florianópolis              SC
# 4     CLI005     Ipê S.A.  Logística  Pequeno  Belo Horizonte              MG
#
#   data_cadastro
# 0    2021-10-13
# 1    2021-03-07
# 2    2021-02-24
# 3    2024-04-21
# 4    15/11/2021

# %%
df_satisfacao = pd.read_csv('dc_satisfacao.csv')
print("Carregamento de 'dc_satisfacao.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:")
print(df_satisfacao.head())
# Out:
# Carregamento de 'dc_satisfacao.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:
#   pesquisa_id projeto_id data_pesquisa  nota_nps  \
# 0     PSQ0001    PRJ0001    2024-05-27       NaN
# 1     PSQ0002    PRJ0003    2025-10-20      10.0
# 2     PSQ0003    PRJ0004    2024-05-08       9.0
# 3     PSQ0004    PRJ0005    2025-03-27       7.0
# 4     PSQ0005    PRJ0006    17/07/2025       6.0
#
#                                 comentario
# 0            Resultado ok, prazo apertado.
# 1                  Documentação impecável.
# 2                  Documentação impecável.
# 3  Bom projeto, comunicação pode melhorar.
# 4             Suporte demorou a responder.

# %%
df_apontamentos = pd.read_csv('dc_apontamentos.csv')
print("Carregamento de 'dc_apontamentos.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:")
print(df_apontamentos.head())
# Out:
# Carregamento de 'dc_apontamentos.csv' bem-sucedido. Aqui estão as 5 primeiras linhas:
#   apontamento_id projeto_id analista_id        data horas            atividade
# 0      APT002473    PRJ0032      ANL006  2026-03-23     6  Reunião com cliente
# 1      APT004798    PRJ0064      ANL008  2026-05-08   6.5         Apresentação
# 2      APT005566    PRJ0079      ANL012  2025-06-02     6               Coleta
# 3      APT000099    PRJ0003      ANL009  2025-09-15   4.5         Documentação
# 4      APT009367    PRJ0134      ANL009  2026-01-22     4            Modelagem

# %% [markdown]
# **CONFIGURANDO UM DIAGNÓSTICO PARA OS DATAFREME**

# %%
def diagnose_dataframe(df, df_name):
    print(f"\n--- Diagnóstico para o DataFrame: {df_name} ---")
    print("\nDimensões do DataFrame (Linhas, Colunas):")
    print(df.shape)

    print("\nInformações Básicas (dtype, non-null count):")
    df.info()

    print("\nValores Nulos por Coluna:")
    print(df.isnull().sum())

    print("\nEstatísticas Descritivas para Colunas Numéricas:")
    print(df.describe())

    print("\nNúmero de Valores Únicos por Coluna:")
    print(df.nunique())

# Aplica a função de diagnóstico a cada DataFrame
diagnose_dataframe(df_analistas, 'df_analistas')
diagnose_dataframe(df_projetos, 'df_projetos')
diagnose_dataframe(df_clientes, 'df_clientes')
diagnose_dataframe(df_satisfacao, 'df_satisfacao')
diagnose_dataframe(df_apontamentos, 'df_apontamentos')
# Out:
# --- Diagnóstico para o DataFrame: df_analistas ---
#
# Dimensões do DataFrame (Linhas, Colunas):
# (24, 6)
#
# Informações Básicas (dtype, non-null count):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   analista_id    24 non-null     object
#  1   analista       24 non-null     object
#  2   squad          24 non-null     object
#  3   senioridade    24 non-null     object
#  4   custo_hora     24 non-null     object
#  5   data_admissao  24 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB
#
# Valores Nulos por Coluna:
# analista_id      0
# analista         0
# squad            0
# senioridade      0
# custo_hora       0
# data_admissao    0
# dtype: int64
#
# Estatísticas Descritivas para Colunas Numéricas:
#        analista_id     analista  squad senioridade custo_hora data_admissao
# count           24           24     24          24         24            24
# unique          24           24      9           4          7            24
# top         ANL001  Ana Barbosa  Bravo      Junior      55.00    2021-12-07
# freq             1            1      4           7          7             1
#
# Número de Valores Únicos por Coluna:
# analista_id      24
# analista         24
# squad             9
# senioridade       4
# custo_hora        7
# data_admissao    24
# dtype: int64
#
# --- Diagnóstico para o DataFrame: df_projetos ---
#
# Dimensões do DataFrame (Linhas, Colunas):
# (141, 11)
#
# Informações Básicas (dtype, non-null count):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   projeto_id         141 non-null    object
#  1   cliente_id         141 non-null    object
#  2   nome_projeto       141 non-null    object
#  3   tipo_servico       141 non-null    object
#  4   squad              141 non-null    object
#  5   status             141 non-null    object
#  6   data_inicio        141 non-null    object
#  7   data_fim_prevista  141 non-null    object
#  8   data_fim_real      128 non-null    object
#  9   horas_vendidas     141 non-null    int64
#  10  valor_contrato     134 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 12.2+ KB
#
# Valores Nulos por Coluna:
# projeto_id            0
# cliente_id            0
# nome_projeto          0
# tipo_servico          0
# squad                 0
# status                0
# data_inicio           0
# data_fim_prevista     0
# data_fim_real        13
# horas_vendidas        0
# valor_contrato        7
# dtype: int64
#
# Estatísticas Descritivas para Colunas Numéricas:
#        horas_vendidas
# count      141.000000
# mean       327.382979
# std        225.486447
# min         51.000000
# 25%        149.000000
# 50%        285.000000
# 75%        430.000000
# max       1030.000000
#
# Número de Valores Únicos por Coluna:
# projeto_id           140
# cliente_id            54
# nome_projeto          87
# tipo_servico          20
# squad                  6
# status                 5
# data_inicio          132
# data_fim_prevista    131
# data_fim_real        117
# horas_vendidas       124
# valor_contrato       133
# dtype: int64
#
# --- Diagnóstico para o DataFrame: df_clientes ---
#
# Dimensões do DataFrame (Linhas, Colunas):
# (62, 7)
#
# Informações Básicas (dtype, non-null count):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cliente_id     62 non-null     object
#  1   cliente        62 non-null     object
#  2   setor          57 non-null     object
#  3   porte          62 non-null     object
#  4   cidade         62 non-null     object
#  5   uf             62 non-null     object
#  6   data_cadastro  62 non-null     object
# dtypes: object(7)
# memory usage: 3.5+ KB
#
# Valores Nulos por Coluna:
# cliente_id       0
# cliente          0
# setor            5
# porte            0
# cidade           0
# uf               0
# data_cadastro    0
# dtype: int64
#
# Estatísticas Descritivas para Colunas Numéricas:
#        cliente_id    cliente  setor    porte     cidade  uf data_cadastro
# count          62         62     57       62         62  62            62
# unique         60         60     17        3         10  19            60
# top        CLI004  Rubi Ltda  Saúde  Pequeno  São Paulo  SP    2024-04-21
# freq            2          2      7       38         11  11             2
#
# Número de Valores Únicos por Coluna:
# cliente_id       60
# cliente          60
# setor            17
# porte             3
# cidade           10
# uf               19
# data_cadastro    60
# dtype: int64
#
# --- Diagnóstico para o DataFrame: df_satisfacao ---
#
# Dimensões do DataFrame (Linhas, Colunas):
# (103, 5)
#
# Informações Básicas (dtype, non-null count):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pesquisa_id    103 non-null    object
#  1   projeto_id     103 non-null    object
#  2   data_pesquisa  103 non-null    object
#  3   nota_nps       95 non-null     float64
#  4   comentario     103 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 4.2+ KB
#
# Valores Nulos por Coluna:
# pesquisa_id      0
# projeto_id       0
# data_pesquisa    0
# nota_nps         8
# comentario       0
# dtype: int64
#
# Estatísticas Descritivas para Colunas Numéricas:
#         nota_nps
# count  95.000000
# mean    8.421053
# std     1.601721
# min     3.000000
# 25%     8.000000
# 50%     9.000000
# 75%    10.000000
# max    10.000000
#
# Número de Valores Únicos por Coluna:
# pesquisa_id      103
# projeto_id       103
# data_pesquisa    100
# nota_nps           8
# comentario        10
# dtype: int64
#
# --- Diagnóstico para o DataFrame: df_apontamentos ---
#
# Dimensões do DataFrame (Linhas, Colunas):
# (9879, 6)
#
# Informações Básicas (dtype, non-null count):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   apontamento_id  9879 non-null   object
#  1   projeto_id      9879 non-null   object
#  2   analista_id     9879 non-null   object
#  3   data            9879 non-null   object
#  4   horas           9879 non-null   object
#  5   atividade       9879 non-null   object
# dtypes: object(6)
# memory usage: 463.2+ KB
#
# Valores Nulos por Coluna:
# apontamento_id    0
# projeto_id        0
# analista_id       0
# data              0
# horas             0
# atividade         0
# dtype: int64
#
# Estatísticas Descritivas para Colunas Numéricas:
#        apontamento_id projeto_id analista_id        data horas atividade
# count            9879       9879        9879        9879  9879      9879
# unique           9799        140          24        2037    23        15
# top         APT002135    PRJ0042      ANL005  2026-06-08     4    Coleta
# freq                2        273         538          57  1667      1232
#
# Número de Valores Únicos por Coluna:
# apontamento_id    9799
# projeto_id         140
# analista_id         24
# data              2037
# horas               23
# atividade           15
# dtype: int64

# %% [markdown]
# ## **LIMPANDO OS DADOS **

# %% [markdown]
# ### **DF ANALISTAS: Limpeza e Tratamento**
#
# #### 1. Coluna `custo_hora`

# %%
# verificando como os dados estão armazenados antes de tratá-los.
df_analistas = pd.read_csv('dc_analistas.csv')

print(df_analistas['custo_hora'].head(10))
# Out:
# 0    150,00
# 1     95.00
# 2     55.00
# 3    210.00
# 4     95.00
# 5     95,00
# 6    210.00
# 7     95.00
# 8     95.00
# 9     55.00
# Name: custo_hora, dtype: object

# %%
# corrigindo o formato e convertendo para número

df_analistas = pd.read_csv('dc_analistas.csv')

df_analistas['custo_hora'] = (
    df_analistas['custo_hora']
    .astype(str)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

print("Coluna 'custo_hora' convertida para float com sucesso.")
print(df_analistas['custo_hora'].head(10))
print(df_analistas['custo_hora'].dtype)
# Out:
# Coluna 'custo_hora' convertida para float com sucesso.
# 0    150.0
# 1     95.0
# 2     55.0
# 3    210.0
# 4     95.0
# 5     95.0
# 6    210.0
# 7     95.0
# 8     95.0
# 9     55.0
# Name: custo_hora, dtype: float64
# float64

# %% [markdown]
# #### 2. Coluna `data_admissao`

# %% [markdown]
# **CORRIGINDO OS FORMATO DAS DATAS**

# %%
#observando os dados
# Nesta coluna os dados são apresentados em formatos diferentes(object)
df_original = pd.read_csv('dc_analistas.csv')

print(df_original['data_admissao'].head(10))
# Out:
# 0     2021-12-07
# 1     2021-08-30
# 2     2024-12-26
# 3     2025-07-28
# 4     24/10/2023
# 5    02-nov-2021
# 6     04/02/2022
# 7     2024-09-05
# 8     2022-02-17
# 9     2025-11-17
# Name: data_admissao, dtype: object

# %%
# Deixando os dados em único formato
datas = [
    '2021-12-07',
    '2021-08-30',
    '2024-12-26',
    '2025-07-28',
    '2023-10-24',
    '2021-11-02',
    '2022-02-04',
    '2024-09-05',
    '2022-02-17',
    '2025-11-17',
    '2023-06-03',
    '2025-02-25',
    '2023-09-11',
    '2022-04-13',
    '2022-04-29',
    '2023-09-23',
    '2023-04-12',
    '2025-11-29',
    '2025-12-17',
    '2025-10-30',
    '2021-08-19',
    '2022-07-14',
    '2023-05-18',
    '2022-08-31'
]

df_analistas['data_admissao'] = pd.to_datetime(datas)
print(df_analistas[['analista', 'data_admissao']])
# Out:
#               analista data_admissao
# 0          Ana Barbosa    2021-12-07
# 1       Bruno Ipiranga    2021-08-30
# 2        Carla Esteves    2024-12-26
# 3        Diego Freitas    2025-07-28
# 4        Elisa Werneck    2023-10-24
# 5        Felipe Duarte    2021-11-02
# 6     Gabriela Werneck    2022-02-04
# 7       Henrique Lopes    2024-09-05
# 8        Isabela Nunes    2022-02-17
# 9           João Lopes    2025-11-17
# 10      Karina Barbosa    2023-06-03
# 11     Lucas Henriques    2025-02-25
# 12     Mariana Ribeiro    2023-09-11
# 13       Nelson Xavier    2022-04-13
# 14    Olívia Henriques    2022-04-29
# 15       Paulo Freitas    2023-09-23
# 16       Queila Xavier    2023-04-12
# 17        Rafael Nunes    2025-11-29
# 18        Sofia Xavier    2025-12-17
# 19      Thiago Freitas    2025-10-30
# 20      Úrsula Marques    2021-08-19
# 21  Vinícius Henriques    2022-07-14
# 22      Wanda Oliveira    2023-05-18
# 23      Yuri Henriques    2022-08-31

# %% [markdown]
# **#### 3. Verificação de Valores Nulos e Duplicados em `df_analistas`**

# %%
# Verificando valores nulos
print("Valores nulos por coluna em df_analistas:")
print(df_analistas.isnull().sum())

# Verificando linhas duplicadas
num_duplicates = df_analistas.duplicated().sum()
print(f"\nNúmero de linhas duplicadas em df_analistas: {num_duplicates}")

if num_duplicates > 0:
    print("Existem linhas duplicadas. Considere removê-las se for apropriado para a análise.")
    # Para exibir as linhas duplicadas (opcional)
    # display(df_analistas[df_analistas.duplicated(keep=False)])
# Out:
# Valores nulos por coluna em df_analistas:
# analista_id      0
# analista         0
# squad            0
# senioridade      0
# custo_hora       0
# data_admissao    0
# dtype: int64
#
# Número de linhas duplicadas em df_analistas: 0

# %% [markdown]
# ### **DF ANALISTAS: Padronização da Coluna `analista`**
#
# Conforme solicitado, vamos padronizar a coluna 'analista' no `df_analistas`. Primeiramente, vou verificar os valores únicos para entender o estado atual da coluna.

# %%
# Verificando os valores únicos e suas contagens na coluna 'analista' de df_analistas
print("Valores únicos e contagens na coluna 'analista' de df_analistas:")
print(df_analistas['analista'].value_counts())

# Padronizando a coluna 'analista': remover espaços em branco e converter para Title Case
df_analistas['analista'] = df_analistas['analista'].str.strip().str.title()

print("\nColuna 'analista' em df_analistas padronizada. Primeiras linhas:")
display(df_analistas.head())
# Out:
# Valores únicos e contagens na coluna 'analista' de df_analistas:
# analista
# Ana Barbosa           1
# Bruno Ipiranga        1
# Carla Esteves         1
# Diego Freitas         1
# Elisa Werneck         1
# Felipe Duarte         1
# Gabriela Werneck      1
# Henrique Lopes        1
# Isabela Nunes         1
# João Lopes            1
# Karina Barbosa        1
# Lucas Henriques       1
# Mariana Ribeiro       1
# Nelson Xavier         1
# Olívia Henriques      1
# Paulo Freitas         1
# Queila Xavier         1
# Rafael Nunes          1
# Sofia Xavier          1
# Thiago Freitas        1
# Úrsula Marques        1
# Vinícius Henriques    1
# Wanda Oliveira        1
# Yuri Henriques        1
# Name: count, dtype: int64
#
# Coluna 'analista' em df_analistas padronizada. Primeiras linhas:
#   analista_id        analista    squad   senioridade  custo_hora data_admissao
# 0      ANL001     Ana Barbosa    ALPHA        Senior       150.0    2021-12-07
# 1      ANL002  Bruno Ipiranga    Bravo         Pleno        95.0    2021-08-30
# 2      ANL003   Carla Esteves  Charlie        Junior        55.0    2024-12-26
# 3      ANL004   Diego Freitas    Delta  Especialista       210.0    2025-07-28
# 4      ANL005   Elisa Werneck     Echo         Pleno        95.0    2023-10-24

# %% [markdown]
# ---

# %% [markdown]
# ### **DF ANALISTAS: Padronização da Coluna `squad`**
#
# Vamos agora padronizar a coluna 'squad' no `df_analistas`. Primeiro, vamos ver os valores únicos existentes e suas contagens.

# %%
# Verificando os valores únicos e suas contagens na coluna 'squad' de df_analistas
print("Valores únicos e contagens na coluna 'squad' de df_analistas:")
print(df_analistas['squad'].value_counts())

# Padronizando a coluna 'squad': remover espaços em branco e converter para Title Case
df_analistas['squad'] = df_analistas['squad'].str.strip().str.title()

print("\nColuna 'squad' em df_analistas padronizada. Primeiras linhas:")
display(df_analistas.head())
# Out:
# Valores únicos e contagens na coluna 'squad' de df_analistas:
# squad
# Bravo      4
# Foxtrot    4
# Delta      4
# Echo       3
# Charlie    3
# Alpha      3
# ALPHA      1
# CHARLIE    1
# ECHO       1
# Name: count, dtype: int64
#
# Coluna 'squad' em df_analistas padronizada. Primeiras linhas:
#   analista_id        analista    squad   senioridade  custo_hora data_admissao
# 0      ANL001     Ana Barbosa    Alpha        Senior       150.0    2021-12-07
# 1      ANL002  Bruno Ipiranga    Bravo         Pleno        95.0    2021-08-30
# 2      ANL003   Carla Esteves  Charlie        Junior        55.0    2024-12-26
# 3      ANL004   Diego Freitas    Delta  Especialista       210.0    2025-07-28
# 4      ANL005   Elisa Werneck     Echo         Pleno        95.0    2023-10-24

# %%
display(df_analistas)
# Out:
#    analista_id            analista    squad   senioridade  custo_hora  \
# 0       ANL001         Ana Barbosa    Alpha        Senior       150.0
# 1       ANL002      Bruno Ipiranga    Bravo         Pleno        95.0
# 2       ANL003       Carla Esteves  Charlie        Junior        55.0
# 3       ANL004       Diego Freitas    Delta  Especialista       210.0
# 4       ANL005       Elisa Werneck     Echo         Pleno        95.0
# 5       ANL006       Felipe Duarte  Foxtrot         Pleno        95.0
# 6       ANL007    Gabriela Werneck    Alpha  Especialista       210.0
# 7       ANL008      Henrique Lopes    Bravo         Pleno        95.0
# 8       ANL009       Isabela Nunes  Charlie         Pleno        95.0
# 9       ANL010          João Lopes    Delta        Junior        55.0
# 10      ANL011      Karina Barbosa     Echo  Especialista       210.0
# 11      ANL012     Lucas Henriques  Foxtrot        Junior        55.0
# 12      ANL013     Mariana Ribeiro    Alpha        Junior        55.0
# 13      ANL014       Nelson Xavier    Bravo  Especialista       210.0
# 14      ANL015    Olívia Henriques  Charlie  Especialista       210.0
# 15      ANL016       Paulo Freitas    Delta  Especialista       210.0
# 16      ANL017       Queila Xavier     Echo        Junior        55.0
# 17      ANL018        Rafael Nunes  Foxtrot        Senior       150.0
# 18      ANL019        Sofia Xavier    Alpha         Pleno        95.0
# 19      ANL020      Thiago Freitas    Bravo        Junior        55.0
# 20      ANL021      Úrsula Marques  Charlie        Senior       150.0
# 21      ANL022  Vinícius Henriques    Delta        Senior       150.0
# 22      ANL023      Wanda Oliveira     Echo        Senior       150.0
# 23      ANL024      Yuri Henriques  Foxtrot        Junior        55.0
#
#    data_admissao
# 0     2021-12-07
# 1     2021-08-30
# 2     2024-12-26
# 3     2025-07-28
# 4     2023-10-24
# 5     2021-11-02
# 6     2022-02-04
# 7     2024-09-05
# 8     2022-02-17
# 9     2025-11-17
# 10    2023-06-03
# 11    2025-02-25
# 12    2023-09-11
# 13    2022-04-13
# 14    2022-04-29
# 15    2023-09-23
# 16    2023-04-12
# 17    2025-11-29
# 18    2025-12-17
# 19    2025-10-30
# 20    2021-08-19
# 21    2022-07-14
# 22    2023-05-18
# 23    2022-08-31

# %% [markdown]
# **#  RENOMEANDO TODAS AS COLUNAS **

# %%
df_analistas = df_analistas.rename(columns={
    'analista_id': 'Analista_id',
    'analista': 'Nome_analista',
    'squad': 'Squad',
    'senioridade': 'Senioridade',
    'custo_hora': 'Custo_hora',
    'data_admissao': 'Data_admissao'
})
print(df_analistas.columns)
# Out:
# Index(['Analista_id', 'Nome_analista', 'Squad', 'Senioridade', 'Custo_hora',
#        'Data_admissao'],
#       dtype='object')

# %%
# Padronização dos textos e removendo os espaços em branco
df_analistas['Nome_analista'] = (
    df_analistas['Nome_analista']
    .str.strip()
)

df_analistas['Squad'] = (
    df_analistas['Squad']
    .str.strip()
    .str.title()
)

df_analistas['Senioridade'] = (
    df_analistas['Senioridade']
    .str.strip()
    .str.title()
)

# %%
df_analistas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Analista_id    24 non-null     object
#  1   Nome_analista  24 non-null     object
#  2   Squad          24 non-null     object
#  3   Senioridade    24 non-null     object
#  4   Custo_hora     24 non-null     float64
#  5   Data_admissao  24 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 1.3+ KB

# %% [markdown]
# **Transformando objct em string**

# %%
#Transformando objct em string
df_analistas = df_analistas.astype({
    'Analista_id': 'string',
    'Nome_analista': 'string',
    'Squad': 'string',
    'Senioridade': 'string'
})

# %%
df_analistas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Analista_id    24 non-null     string
#  1   Nome_analista  24 non-null     string
#  2   Squad          24 non-null     string
#  3   Senioridade    24 non-null     string
#  4   Custo_hora     24 non-null     float64
#  5   Data_admissao  24 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), string(4)
# memory usage: 1.3 KB

# %% [markdown]
# ## **LIMPANDO OS DADOS - DF CLIENTES**

# %%
#VERIFICANDO AS INFORMAÇÕES DO DATAFREME
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cliente_id     62 non-null     object
#  1   cliente        62 non-null     object
#  2   setor          57 non-null     object
#  3   porte          62 non-null     object
#  4   cidade         62 non-null     object
#  5   uf             62 non-null     object
#  6   data_cadastro  62 non-null     object
# dtypes: object(7)
# memory usage: 3.5+ KB

# %% [markdown]
# **Vamos usar um comando que nos possibilita oberservar as caraterísticas dos dados em cada coluna**

# %%
# Esse comando serve para verificar a quantidade de dados e como eles estão distribuidos neste DataFrame
df_clientes.describe(include="all")
# Out:
#        cliente_id    cliente  setor    porte     cidade  uf data_cadastro
# count          62         62     57       62         62  62            62
# unique         60         60     17        3         10  19            60
# top        CLI004  Rubi Ltda  Saúde  Pequeno  São Paulo  SP    2024-04-21
# freq            2          2      7       38         11  11             2

# %%
# visualizando os clientes com os dados faltantes
df_clientes[df_clientes['setor'].isnull()]
# Out:
#    cliente_id             cliente setor    porte          cidade  \
# 0      CLI001         Umbu S.A.     NaN  Pequeno  Rio de Janeiro
# 12     CLI013      Windsor Brasil   NaN    Médio       São Paulo
# 24     CLI025  Umbu Participações   NaN  Pequeno       São Paulo
# 36     CLI037        Serena Group   NaN   Grande        Curitiba
# 48     CLI049        Cristal Ltda   NaN  Pequeno       São Paulo
#
#                 uf data_cadastro
# 0   Rio de Janeiro    2021-10-13
# 12              SP   30-dez-2023
# 24              SP    2023-07-19
# 36              PR    2022-01-25
# 48              SP    11/01/2025

# %%
#Preencher os valores faltantes por (Não informado)

df_clientes['setor'] = df_clientes['setor'].fillna('Não informado')

df_clientes.head()
# Out:
#   cliente_id      cliente          setor    porte          cidade  \
# 0     CLI001  Umbu S.A.    Não informado  Pequeno  Rio de Janeiro
# 1     CLI002   Xingu S.A.      Indústria    Médio   Florianópolis
# 2     CLI003  Aurora S.A.          Saúde    Médio        Curitiba
# 3     CLI004    Rubi Ltda      Logística  Pequeno   Florianópolis
# 4     CLI005     Ipê S.A.      Logística  Pequeno  Belo Horizonte
#
#                uf data_cadastro
# 0  Rio de Janeiro    2021-10-13
# 1              SC    2021-03-07
# 2              PR    2021-02-24
# 3              SC    2024-04-21
# 4              MG    15/11/2021

# %%
#Padronizando a coluna setor
df_clientes["setor"] = df_clientes["setor"].str.strip().str.title()
df_clientes["setor"].value_counts(dropna=False)
# Out:
# setor
# Educação                9
# Saúde                   8
# Energia                 7
# Setor Público           7
# Serviços Financeiros    7
# Tecnologia              6
# Não Informado           5
# Logística               4
# Indústria               3
# Agronegócio             3
# Varejo                  3
# Name: count, dtype: int64

# %% [markdown]
# Padronizando as datas

# %%
#Identificando os valores que contêm letras
df_clientes[
    df_clientes["data_cadastro"].astype(str).str.contains(
        r"[A-Za-z]",
        regex=True,
        na=False
    )
][["cliente_id", "data_cadastro"]]
# Out:
#    cliente_id data_cadastro
# 5      CLI006   06-jan-2023
# 12     CLI013   30-dez-2023
# 19     CLI020   11-out-2021
# 26     CLI027   27-nov-2021
# 33     CLI034   13-fev-2021
# 40     CLI041   26-nov-2025
# 47     CLI048   07-nov-2023
# 54     CLI055   06-dez-2025

# %% [markdown]
# A coluna possue padrões diferentes.
#
# AAAA-MM-DD → 2021-10-13
# DD/MM/AAAA → 15/11/2021
# DD-mês-AAAA → 06-jan-2023
# MM/DD/AAAA → 05/26/2021, 08/28/2024, 01/18/2024
#
# - Vamos criar um cópia do Dataframe para realizar a conversão sem correr o risco de estragar os dados do arquivo original.

# %%
#convertendo em sem altera o datafreme original

df_clientes["data_cadastro_original"] = df_clientes["data_cadastro"]
df_clientes["data_cadastro"] = pd.to_datetime(
    df_clientes["data_cadastro"],
    errors="coerce"
)

# %%
df_clientes[["data_cadastro_original", "data_cadastro"]].head(10)
# Out:
#   data_cadastro_original data_cadastro
# 0             2021-10-13    2021-10-13
# 1             2021-03-07    2021-03-07
# 2             2021-02-24    2021-02-24
# 3             2024-04-21    2024-04-21
# 4             15/11/2021           NaT
# 5            06-jan-2023           NaT
# 6             02/03/2025           NaT
# 7             2022-08-24    2022-08-24
# 8             2024-12-13    2024-12-13
# 9             2025-10-18    2025-10-18

# %%
df_clientes[
    df_clientes["data_cadastro"].isna()
][["cliente_id", "data_cadastro_original"]]
# Out:
#    cliente_id data_cadastro_original
# 4      CLI005             15/11/2021
# 5      CLI006            06-jan-2023
# 6      CLI007             02/03/2025
# 11     CLI012             01/07/2022
# 12     CLI013            30-dez-2023
# 13     CLI014             08/03/2024
# 18     CLI019             28/05/2023
# 19     CLI020            11-out-2021
# 20     CLI021             11/10/2021
# 25     CLI026             18/11/2025
# 26     CLI027            27-nov-2021
# 27     CLI028             02/09/2021
# 32     CLI033             07/10/2024
# 33     CLI034            13-fev-2021
# 34     CLI035             05/26/2021
# 39     CLI040             08/07/2023
# 40     CLI041            26-nov-2025
# 41     CLI042             08/28/2024
# 46     CLI047             28/04/2021
# 47     CLI048            07-nov-2023
# 48     CLI049             11/01/2025
# 53     CLI054             31/05/2021
# 54     CLI055            06-dez-2025
# 55     CLI056             01/18/2024
# 61     CLI028             02/09/2021

# %%
#convertendo os meses
meses = {
    "jan": "01",
    "fev": "02",
    "mar": "03",
    "abr": "04",
    "mai": "05",
    "jun": "06",
    "jul": "07",
    "ago": "08",
    "set": "09",
    "out": "10",
    "nov": "11",
    "dez": "12"
}

# %%
#Funsão para conversão do formato da data
def padronizar_data(data):

    if pd.isna(data):
        return pd.NaT

    data = str(data).strip().lower()

    # Datas com mês escrito: 06-jan-2023
    for mes, numero in meses.items():
        data = data.replace(f"-{mes}-", f"-{numero}-")

    # AAAA-MM-DD
    if len(data) == 10 and data[4] == "-":
        return pd.to_datetime(data, format="%Y-%m-%d", errors="coerce")

    # Datas com /
    if "/" in data:
        partes = data.split("/")

        if len(partes) == 3:
            primeiro, segundo, ano = partes

            # Se o segundo número > 12, necessariamente é MM/DD/YYYY
            if int(segundo) > 12:
                return pd.to_datetime(data, format="%m/%d/%Y", errors="coerce")

            # Caso contrário, assumimos padrão brasileiro DD/MM/YYYY
            return pd.to_datetime(data, format="%d/%m/%Y", errors="coerce")

    # Datas com hífen depois da conversão dos meses
    return pd.to_datetime(data, format="%d-%m-%Y", errors="coerce")

# %%
df_clientes["data_cadastro"] = (
    df_clientes["data_cadastro_original"]
    .apply(padronizar_data)
)

# %%
#Verificando para validar
df_clientes[
    ["cliente_id", "data_cadastro_original", "data_cadastro"]
].head(20)
# Out:
#    cliente_id data_cadastro_original data_cadastro
# 0      CLI001             2021-10-13    2021-10-13
# 1      CLI002             2021-03-07    2021-03-07
# 2      CLI003             2021-02-24    2021-02-24
# 3      CLI004             2024-04-21    2024-04-21
# 4      CLI005             15/11/2021    2021-11-15
# 5      CLI006            06-jan-2023    2023-01-06
# 6      CLI007             02/03/2025    2025-03-02
# 7      CLI008             2022-08-24    2022-08-24
# 8      CLI009             2024-12-13    2024-12-13
# 9      CLI010             2025-10-18    2025-10-18
# 10     CLI011             2025-09-05    2025-09-05
# 11     CLI012             01/07/2022    2022-07-01
# 12     CLI013            30-dez-2023    2023-12-30
# 13     CLI014             08/03/2024    2024-03-08
# 14     CLI015             2025-05-09    2025-05-09
# 15     CLI016             2021-05-16    2021-05-16
# 16     CLI017             2023-03-22    2023-03-22
# 17     CLI018             2022-05-21    2022-05-21
# 18     CLI019             28/05/2023    2023-05-28
# 19     CLI020            11-out-2021    2021-10-11

# %%
df_clientes["data_cadastro"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clientes.head(20)
# Out:
#    cliente_id                cliente                 setor    porte  \
# 0      CLI001            Umbu S.A.           Não Informado  Pequeno
# 1      CLI002             Xingu S.A.             Indústria    Médio
# 2      CLI003            Aurora S.A.                 Saúde    Médio
# 3      CLI004              Rubi Ltda             Logística  Pequeno
# 4      CLI005               Ipê S.A.             Logística  Pequeno
# 5      CLI006  Granito Participações             Indústria  Pequeno
# 6      CLI007    Coral Participações              Educação   Grande
# 7      CLI008        Orion Holding               Logística  Pequeno
# 8      CLI009         Basalto Brasil               Energia    Médio
# 9      CLI010           Cristal S.A.              Educação   Grande
# 10     CLI011         Horizonte S.A.              Educação    Médio
# 11     CLI012            Laguna Ltda               Energia  Pequeno
# 12     CLI013         Windsor Brasil         Não Informado    Médio
# 13     CLI014             Xingu Ltda           Agronegócio  Pequeno
# 14     CLI015      Windsor Holding                 Energia   Grande
# 15     CLI016            Boreal Ltda               Energia  Pequeno
# 16     CLI017        Granito Holding                 Saúde    Médio
# 17     CLI018       Duna Azul Brasil  Serviços Financeiros  Pequeno
# 18     CLI019          Xingu Holding              Educação    Médio
# 19     CLI020      Duna Azul Holding               Energia  Pequeno
#
#             cidade  uf data_cadastro
# 0   Rio de Janeiro  RJ    2021-10-13
# 1    Florianópolis  SC    2021-03-07
# 2         Curitiba  PR    2021-02-24
# 3    Florianópolis  SC    2024-04-21
# 4   Belo Horizonte  MG    2021-11-15
# 5        São Paulo  SP    2023-01-06
# 6        Fortaleza  CE    2025-03-02
# 7        São Paulo  SP    2022-08-24
# 8        Fortaleza  CE    2024-12-13
# 9         Curitiba  PR    2025-10-18
# 10        Salvador  BA    2025-09-05
# 11          Recife  PE    2022-07-01
# 12       São Paulo  SP    2023-12-30
# 13  Belo Horizonte  MG    2024-03-08
# 14        Curitiba  PR    2025-05-09
# 15  Rio de Janeiro  RJ    2021-05-16
# 16          Recife  PE    2023-03-22
# 17        Brasília  DF    2022-05-21
# 18   Florianópolis  SC    2023-05-28
# 19        Salvador  BA    2021-10-11

# %%
#Substituindo as colunas

df_clientes.head(10)
# Out:
#   cliente_id                cliente          setor    porte          cidade  \
# 0     CLI001            Umbu S.A.    Não Informado  Pequeno  Rio de Janeiro
# 1     CLI002             Xingu S.A.      Indústria    Médio   Florianópolis
# 2     CLI003            Aurora S.A.          Saúde    Médio        Curitiba
# 3     CLI004              Rubi Ltda      Logística  Pequeno   Florianópolis
# 4     CLI005               Ipê S.A.      Logística  Pequeno  Belo Horizonte
# 5     CLI006  Granito Participações      Indústria  Pequeno       São Paulo
# 6     CLI007    Coral Participações       Educação   Grande       Fortaleza
# 7     CLI008        Orion Holding        Logística  Pequeno       São Paulo
# 8     CLI009         Basalto Brasil        Energia    Médio       Fortaleza
# 9     CLI010           Cristal S.A.       Educação   Grande        Curitiba
#
#                uf data_cadastro
# 0  Rio de Janeiro    2021-10-13
# 1              SC    2021-03-07
# 2              PR    2021-02-24
# 3              SC    2024-04-21
# 4              MG    2021-11-15
# 5              SP    2023-01-06
# 6              CE    2025-03-02
# 7              SP    2022-08-24
# 8              CE    2024-12-13
# 9              PR    2025-10-18

# %% [markdown]
# **PADRONIZANDO A COLUNA UF**

# %%
df_clientes['uf'].unique()
# Out:
# array(['Rio de Janeiro', 'SC', 'PR', 'MG', 'SP', 'CE', 'BA', 'pe', 'RJ',
#        'PE', 'Brasília', 'sc', 'RS', 'DF', 'pr', 'Curitiba', 'df',
#        'Recife', 'rs'], dtype=object)

# %%
# 1. Padroniza tudo para maiúsculas (corrige 'pe', 'sc', 'pr', 'df', 'rs')
df_clientes['uf'] = df_clientes['uf'].str.strip().str.upper()

# 2. Mapeia cidades e nomes por extenso para as siglas corretas
mapeamento_uf = {
    'RIO DE JANEIRO': 'RJ',
    'BRASÍLIA': 'DF',
    'CURITIBA': 'PR',
    'RECIFE': 'PE'
}

# 3. Aplica a substituição
df_clientes['uf'] = df_clientes['uf'].replace(mapeamento_uf)

# 4. Confere o resultado limpo
df_clientes['uf'].unique()
# Out:
# array(['RJ', 'SC', 'PR', 'MG', 'SP', 'CE', 'BA', 'PE', 'DF', 'RS'],
#       dtype=object)

# %%
df_clientes['uf'].head(20)
# Out:
# 0     RJ
# 1     SC
# 2     PR
# 3     SC
# 4     MG
# 5     SP
# 6     CE
# 7     SP
# 8     CE
# 9     PR
# 10    BA
# 11    PE
# 12    SP
# 13    MG
# 14    PR
# 15    RJ
# 16    PE
# 17    DF
# 18    SC
# 19    BA
# Name: uf, dtype: object

# %%
df_clientes.head(20)
# Out:
#    cliente_id                cliente                 setor    porte  \
# 0      CLI001            Umbu S.A.           Não Informado  Pequeno
# 1      CLI002             Xingu S.A.             Indústria    Médio
# 2      CLI003            Aurora S.A.                 Saúde    Médio
# 3      CLI004              Rubi Ltda             Logística  Pequeno
# 4      CLI005               Ipê S.A.             Logística  Pequeno
# 5      CLI006  Granito Participações             Indústria  Pequeno
# 6      CLI007    Coral Participações              Educação   Grande
# 7      CLI008        Orion Holding               Logística  Pequeno
# 8      CLI009         Basalto Brasil               Energia    Médio
# 9      CLI010           Cristal S.A.              Educação   Grande
# 10     CLI011         Horizonte S.A.              Educação    Médio
# 11     CLI012            Laguna Ltda               Energia  Pequeno
# 12     CLI013         Windsor Brasil         Não Informado    Médio
# 13     CLI014             Xingu Ltda           Agronegócio  Pequeno
# 14     CLI015      Windsor Holding                 Energia   Grande
# 15     CLI016            Boreal Ltda               Energia  Pequeno
# 16     CLI017        Granito Holding                 Saúde    Médio
# 17     CLI018       Duna Azul Brasil  Serviços Financeiros  Pequeno
# 18     CLI019          Xingu Holding              Educação    Médio
# 19     CLI020      Duna Azul Holding               Energia  Pequeno
#
#             cidade  uf data_cadastro
# 0   Rio de Janeiro  RJ    2021-10-13
# 1    Florianópolis  SC    2021-03-07
# 2         Curitiba  PR    2021-02-24
# 3    Florianópolis  SC    2024-04-21
# 4   Belo Horizonte  MG    2021-11-15
# 5        São Paulo  SP    2023-01-06
# 6        Fortaleza  CE    2025-03-02
# 7        São Paulo  SP    2022-08-24
# 8        Fortaleza  CE    2024-12-13
# 9         Curitiba  PR    2025-10-18
# 10        Salvador  BA    2025-09-05
# 11          Recife  PE    2022-07-01
# 12       São Paulo  SP    2023-12-30
# 13  Belo Horizonte  MG    2024-03-08
# 14        Curitiba  PR    2025-05-09
# 15  Rio de Janeiro  RJ    2021-05-16
# 16          Recife  PE    2023-03-22
# 17        Brasília  DF    2022-05-21
# 18   Florianópolis  SC    2023-05-28
# 19        Salvador  BA    2021-10-11

# %% [markdown]
# **Excluindo as linhas duplicadas**

# %%
df_clientes.duplicated().sum()
# Out:
# np.int64(2)

# %%
df_clientes[df_clientes.duplicated(subset=['cliente_id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [cliente_id, cliente, setor, porte, cidade, uf, data_cadastro]
# Index: []

# %%
#Excluindo as linhas duplicadas
df_clientes = df_clientes.drop_duplicates(subset=['cliente_id'])

# %%
df_clientes.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Convertendo "Objetc" em "String"**

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cliente_id     60 non-null     object
#  1   cliente        60 non-null     object
#  2   setor          60 non-null     object
#  3   porte          60 non-null     object
#  4   cidade         60 non-null     object
#  5   uf             60 non-null     object
#  6   data_cadastro  60 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(6)
# memory usage: 3.8+ KB

# %%
# Seleciona todas as colunas que atualmente são 'object' e converte para 'string'
df_clientes = df_clientes.astype({
    'cliente_id': 'string',
    'cliente': 'string',
    'setor': 'string',
    'porte': 'string',
    'cidade': 'string',
    'uf': 'string'
})

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cliente_id     60 non-null     string
#  1   cliente        60 non-null     string
#  2   setor          60 non-null     string
#  3   porte          60 non-null     string
#  4   cidade         60 non-null     string
#  5   uf             60 non-null     string
#  6   data_cadastro  60 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), string(6)
# memory usage: 3.8 KB

# %% [markdown]
# ### **DF-PROJETOS**

# %%
df_projetos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   projeto_id         141 non-null    object
#  1   cliente_id         141 non-null    object
#  2   nome_projeto       141 non-null    object
#  3   tipo_servico       141 non-null    object
#  4   squad              141 non-null    object
#  5   status             141 non-null    object
#  6   data_inicio        141 non-null    object
#  7   data_fim_prevista  141 non-null    object
#  8   data_fim_real      128 non-null    object
#  9   horas_vendidas     141 non-null    int64
#  10  valor_contrato     134 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 12.2+ KB

# %%
df_projetos.describe(include="all")
# Out:
#        projeto_id cliente_id              nome_projeto  tipo_servico squad  \
# count         141        141                       141           141   141
# unique        140         54                        87            20     6
# top       PRJ0010     CLI020  Dashboard BI - Horizonte  Dashboard BI  Echo
# freq            2          8                         5            26    30
# mean          NaN        NaN                       NaN           NaN   NaN
# std           NaN        NaN                       NaN           NaN   NaN
# min           NaN        NaN                       NaN           NaN   NaN
# 25%           NaN        NaN                       NaN           NaN   NaN
# 50%           NaN        NaN                       NaN           NaN   NaN
# 75%           NaN        NaN                       NaN           NaN   NaN
# max           NaN        NaN                       NaN           NaN   NaN
#
#            status data_inicio data_fim_prevista data_fim_real  horas_vendidas  \
# count         141         141               141           128      141.000000
# unique          5         132               131           117             NaN
# top     Concluído  2026-03-30        2024-10-28    10/21/2024             NaN
# freq          120           3                 2             2             NaN
# mean          NaN         NaN               NaN           NaN      327.382979
# std           NaN         NaN               NaN           NaN      225.486447
# min           NaN         NaN               NaN           NaN       51.000000
# 25%           NaN         NaN               NaN           NaN      149.000000
# 50%           NaN         NaN               NaN           NaN      285.000000
# 75%           NaN         NaN               NaN           NaN      430.000000
# max           NaN         NaN               NaN           NaN     1030.000000
#
#        valor_contrato
# count             134
# unique            133
# top          98986.73
# freq                2
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %% [markdown]
# Analisando o DataFreme vereicamos que:
# **Datas estão com texto (object):
#
# data_inicio, data_fim_prevista e data_fim_real estão salvas como texto. Precisam ser convertidas para datetime64[ns].
#
# valor_contrato como Texto (object) precisa ser convertido em string
#
# O valor financeiro está como texto, precisa ser convertido para número (float).
#
# Valores Nulos
#
# data_fim_real: 13 valores nulos (normal se o projeto ainda estiver em andamento/em aberto).
#
# valor_contrato: 7 valores nulos (precisam de atenção/imputação)**

# %%
#Código de Tratamento

# 1. Converter colunas de data para datetime
colunas_data = ['data_inicio', 'data_fim_prevista', 'data_fim_real']
for col in colunas_data:
    df_projetos[col] = pd.to_datetime(df_projetos[col], errors='coerce')

# 2. Limpar e converter a coluna valor_contrato para float
# Remove "R$", pontos de milhar e troca vírgula por ponto
df_projetos['valor_contrato'] = (
    df_projetos['valor_contrato']
    .astype(str)
    .str.replace('R$', '', regex=False)
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .str.strip()
)

# Converte para numérico (transforma erros/textos inválidos em NaN)
df_projetos['valor_contrato'] = pd.to_numeric(df_projetos['valor_contrato'], errors='coerce')

# 3. (Opcional) Converter colunas de texto genéricas para string
colunas_texto = ['projeto_id', 'cliente_id', 'nome_projeto', 'tipo_servico', 'squad', 'status']
df_projetos[colunas_texto] = df_projetos[colunas_texto].astype('string')

# %%
df_projetos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   projeto_id         141 non-null    string
#  1   cliente_id         141 non-null    string
#  2   nome_projeto       141 non-null    string
#  3   tipo_servico       141 non-null    string
#  4   squad              141 non-null    string
#  5   status             141 non-null    string
#  6   data_inicio        81 non-null     datetime64[ns]
#  7   data_fim_prevista  80 non-null     datetime64[ns]
#  8   data_fim_real      27 non-null     datetime64[ns]
#  9   horas_vendidas     141 non-null    int64
#  10  valor_contrato     134 non-null    float64
# dtypes: datetime64[ns](3), float64(1), int64(1), string(6)
# memory usage: 12.2 KB

# %%
# Cria uma tabela comparativa com contagem e percentual de nulos
resumo_nulos = pd.DataFrame({
    'Total Nulos': df_projetos.isna().sum()

})

# Filtra apenas as colunas que têm pelo menos 1 valor nulo
resumo_nulos[resumo_nulos['Total Nulos'] > 0]
# Out:
#                    Total Nulos
# data_inicio                 60
# data_fim_prevista           61
# data_fim_real              114
# valor_contrato               7

# %%
df_projetos.head(10)
# Out:
#   projeto_id cliente_id                  nome_projeto          tipo_servico  \
# 0    PRJ0001     CLI013        Dashboard BI - Windsor        Dashboard B.I.
# 1    PRJ0002     CLI022   Diagnóstico de Dados - Umbu  Diagnóstico de Dados
# 2    PRJ0003     CLI051   Pipeline de Dados - Cristal     Pipeline de Dados
# 3    PRJ0004     CLI060         Dashboard BI - Kairós          Dashboard BI
# 4    PRJ0005     CLI020       Modelo Preditivo - Duna      Modelo Preditivo
# 5    PRJ0006     CLI048  Pipeline de Dados - Pantanal     Pipeline de Dados
# 6    PRJ0007     CLI021      Data Warehouse - Quartzo        Data Warehouse
# 7    PRJ0008     CLI041      Data Warehouse - Everest        Data Warehouse
# 8    PRJ0009     CLI031        Dashboard BI - Everest          Dashboard BI
# 9    PRJ0010     CLI001       Modelo Preditivo - Umbu      Modelo Preditivo
#
#      squad        status data_inicio data_fim_prevista data_fim_real  \
# 0    Delta     CONCLUÍDO  2024-03-19        2024-05-06    2024-08-05
# 1    Alpha     Cancelado  2024-10-01        2024-10-28           NaT
# 2  Charlie     Concluído  2025-06-16               NaT    2025-10-15
# 3     Echo     Concluído  2024-03-19               NaT           NaT
# 4     Echo     Concluído         NaT               NaT           NaT
# 5    Bravo     Concluído         NaT        2025-06-16           NaT
# 6    Delta     Concluído         NaT        2025-02-17           NaT
# 7     Echo  Em andamento  2026-02-16        2026-09-04           NaT
# 8     Echo     Concluído  2025-10-13        2025-11-17           NaT
# 9    Alpha     Concluído  2024-07-08               NaT    2024-10-21
#
#    horas_vendidas  valor_contrato
# 0             288             NaN
# 1              89      2404451.00
# 2             423      9152558.00
# 3             220      4740901.00
# 4             338        61970.49
# 5             515     11028535.00
# 6             852     16981961.00
# 7             743     13384127.00
# 8             157        34835.02
# 9             578      9898673.00

# %%
# Display the first few rows to show the changes
display(df_projetos.head(10))
# Out:
#   projeto_id cliente_id                  nome_projeto          tipo_servico  \
# 0    PRJ0001     CLI013        Dashboard BI - Windsor        Dashboard B.I.
# 1    PRJ0002     CLI022   Diagnóstico de Dados - Umbu  Diagnóstico de Dados
# 2    PRJ0003     CLI051   Pipeline de Dados - Cristal     Pipeline de Dados
# 3    PRJ0004     CLI060         Dashboard BI - Kairós          Dashboard BI
# 4    PRJ0005     CLI020       Modelo Preditivo - Duna      Modelo Preditivo
# 5    PRJ0006     CLI048  Pipeline de Dados - Pantanal     Pipeline de Dados
# 6    PRJ0007     CLI021      Data Warehouse - Quartzo        Data Warehouse
# 7    PRJ0008     CLI041      Data Warehouse - Everest        Data Warehouse
# 8    PRJ0009     CLI031        Dashboard BI - Everest          Dashboard BI
# 9    PRJ0010     CLI001       Modelo Preditivo - Umbu      Modelo Preditivo
#
#      squad        status data_inicio data_fim_prevista data_fim_real  \
# 0    Delta     CONCLUÍDO  2024-03-19        2024-05-06    2024-08-05
# 1    Alpha     Cancelado  2024-10-01        2024-10-28           NaT
# 2  Charlie     Concluído  2025-06-16               NaT    2025-10-15
# 3     Echo     Concluído  2024-03-19               NaT           NaT
# 4     Echo     Concluído         NaT               NaT           NaT
# 5    Bravo     Concluído         NaT        2025-06-16           NaT
# 6    Delta     Concluído         NaT        2025-02-17           NaT
# 7     Echo  Em andamento  2026-02-16        2026-09-04           NaT
# 8     Echo     Concluído  2025-10-13        2025-11-17           NaT
# 9    Alpha     Concluído  2024-07-08               NaT    2024-10-21
#
#    horas_vendidas  valor_contrato
# 0             288      3820472.00
# 1              89      2404451.00
# 2             423      9152558.00
# 3             220      4740901.00
# 4             338        61970.49
# 5             515     11028535.00
# 6             852     16981961.00
# 7             743     13384127.00
# 8             157        34835.02
# 9             578      9898673.00
